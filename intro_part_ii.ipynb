# %% [markdown]
# # An Introduction to Inference in Pyro
# Much of modern machine learning can be cast as approximate inference and expressed succinctly in a language like Pyro. To motivate the rest of this tutorial, let's build a generative model for a simple physical problem so that we can use Pyro's inference machinery to solve it. However, we will first import the required modules for this tutorial:

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

import pyro
import pyro.infer
import pyro.optim
import pyro.distributions as dist

pyro.set_rng_seed(101)

# %% [markdown]
# ## A Simple Example
# Suppose we are trying to figure out how much something weighs, but the scale we're using is unreliable and gives slightly different answers every time we weigh the same object.  We could try to compensate for this variability by integrating the noisy measurement information with a guess based on some prior knowledge about the object, like its density or material properties.  The following model encodes this process:
#
# $${\sf weight} \, | \, {\sf guess} \sim \cal {\sf Normal}({\sf guess}, 1) $$
# $${\sf measurement} \, | \, {\sf guess}, {\sf weight} \sim {\sf Normal}({\sf weight}, 0.75)$$
#
# Note that this is a model not only for our belief over weight, but also for the result of taking a measurement of it. The model corresponds to the following stochastic function:

# %%
def scale(guess):
    weight = pyro.sample("weight", dist.Normal(guess, 1.0))
    m = pyro.sample("measurement", dist.Normal(weight, 0.05))
    print("Scale fn")
    print("guess =",guess,"weight =",weight,"measurement =",m)
    return m

# %%
scale(8.5)
# Out:
# Scale fn
# guess = 8.5 weight = tensor(8.8222) measurement = tensor(8.8598)
# tensor(8.8598)

# %% [markdown]
# ## Conditioning
#
# The real utility of probabilistic programming is in the ability to condition generative models on observed data and infer the latent factors that might have produced that data. In Pyro, we separate the expression of conditioning from its evaluation via inference, making it possible to write a model once and condition it on many different observations.  Pyro supports constraining a model's internal `sample` statements to be equal to a given set of observations.
#
# Consider `scale` once again.  Suppose we want to sample from the  distribution of `weight` given input `guess = 8.5`, but now we have observed that `measurement == 9.5`. That is, we wish to *infer* the distribution:
# $$({\sf weight} \, | \, {\sf guess}, {\sf measurement} = 9.5) \sim \, ? $$
#
# Pyro provides the function `pyro.condition` to allow us to constrain the values of sample statements.  `pyro.condition` is a higher-order function that takes a model and a dictionary of observations and returns a new model that has the same input and output signatures but always uses the given values at observed `sample` statements:

# %%
conditioned_scale = pyro.condition(scale, data={"measurement": 10.5})

# %%
print(conditioned_scale)
# Out:
# <function Messenger.__call__.<locals>._wraps at 0x11e1582f0>

# %%
print(conditioned_scale(6.5))
# Out:
# Scale fn
# guess = 6.5 weight = tensor(4.9615) measurement = 10.5
# 10.5

# %% [markdown]
# Because it behaves just like an ordinary Python function, conditioning can be deferred or parametrized with Python's `lambda` or `def`:

# %%
def deferred_conditioned_scale(measurement, guess):
    return pyro.condition(scale, data={"measurement": measurement})(guess)

# %%
print(deferred_conditioned_scale)
# Out:
# <function deferred_conditioned_scale at 0x11d8c99d8>

# %%
deferred_conditioned_scale(10.4,10)
# Out:
# Scale fn
# guess = 10 weight = tensor(9.5566) measurement = 10.4
# 10.4

# %% [markdown]
# In some cases it might be more convenient to pass observations directly to individual `pyro.sample` statements instead of using `pyro.condition`.  The optional `obs` keyword argument is reserved by `pyro.sample` for that purpose:

# %%
def scale_obs(guess):  # equivalent to conditioned_scale above
    weight = pyro.sample("weight", dist.Normal(guess, 1.))
     # here we condition on measurement == 9.5
    return pyro.sample("measurement", dist.Normal(weight, 1.), obs=9.5)

# %%
scale_obs(8.7)
# Out:
# 9.5

# %% [markdown]
# Finally, in addition to `pyro.condition` for incorporating observations, Pyro also contains `pyro.do`, an implementation of Pearl's `do`-operator used for causal inference with an identical interface to `pyro.condition`.  `condition` and `do` can be mixed and composed freely, making Pyro a powerful tool for model-based causal inference.

# %% [markdown]
# ## Flexible Approximate Inference With Guide Functions
#
# Let's return to `conditioned_scale`.  Now that we have conditioned on an observation of `measurement`, we can use Pyro's approximate inference algorithms to estimate the distribution over `weight` given `guess` and `measurement == data`.

# %% [markdown]
# Inference algorithms in Pyro, such as `pyro.infer.SVI`, allow us to use arbitrary stochastic functions, which we will call *guide functions* or *guides*, as approximate posterior distributions.  Guide functions must satisfy these two criteria to be valid approximations for a particular model:
# 1. all unobserved (i.e., not conditioned) sample statements that appear in the model appear in the guide.
# 2. the guide has the same input signature as the model (i.e., takes the same arguments)
#
# Guide functions can serve as programmable, data-dependent proposal distributions for importance sampling, rejection sampling, sequential Monte Carlo, MCMC, and independent Metropolis-Hastings, and as variational distributions or inference networks for stochastic variational inference.  Currently, importance sampling, MCMC, and stochastic variational inference are implemented in Pyro, and we plan to add other algorithms in the future.
#
# Although the precise meaning of the guide is different across different inference algorithms, the guide function should generally be chosen so that, in principle, it is flexible enough to closely approximate the distribution over all unobserved `sample` statements in the model.

# %% [markdown]
# In the case of `scale`, it turns out that the true posterior distribution over `weight` given `guess` and `measurement` is actually ${\sf Normal}(9.14, 0.6)$. As the model is quite simple, we are able to determine our posterior distribution of interest analytically (for derivation, see for example Section 3.4 of http://www.stat.cmu.edu/~brian/463-663/week09/Chapter%2003.pdf ).

# %%
def perfect_guide(guess):
    loc =(0.75**2 * guess + 9.5) / (1 + 0.75**2) # 9.14
    scale = np.sqrt(0.75**2/(1 + 0.75**2)) # 0.6
    return pyro.sample("weight", dist.Normal(loc, scale))

# %%
perfect_guide(10)
# Out:
# tensor(9.4011)

# %% [markdown]
# ## Parametrized Stochastic Functions and Variational Inference
#
# Although we could write out the exact posterior distribution for `scale`, in general it is intractable to specify a guide that is a good approximation to the posterior distribution of an arbitrary conditioned stochastic function.  In fact, stochastic functions for which we can determine the true posterior exactly are the exception rather than the rule. For example, even a version of our `scale` example with a nonlinear function in the middle may be intractable:

# %%
def intractable_scale(guess):
    weight = pyro.sample("weight", dist.Normal(guess, 1.0))
    return pyro.sample("measurement", dist.Normal(some_nonlinear_function(weight), 0.75))

# %% [markdown]
# What we can do instead is use the top-level function `pyro.param` to specify a *family* of guides indexed by named parameters, and search for the member of that family that is the best approximation according to some loss function.  This approach to approximate posterior inference is called *variational inference*.
#
# `pyro.param` is a frontend for Pyro's key-value *parameter store*, which is described in more detail in the documentation. Like `pyro.sample`, `pyro.param` is always called with a name as its first argument.  The first time `pyro.param` is called with a particular name, it stores its argument in the parameter store and then returns that value.  After that, when it is called with that name, it returns the value from the parameter store regardless of any other arguments.  It is similar to `simple_param_store.setdefault` here, but with some additional tracking and management functionality.
#
# ```python
# simple_param_store = {}
# a = simple_param_store.setdefault("a", torch.randn(1))
# ```
#
# For example, we can parametrize `a` and `b` in `scale_posterior_guide` instead of specifying them by hand:

# %%
def scale_parametrized_guide(guess):
    a = pyro.param("a", torch.tensor(guess))
    b = pyro.param("b", torch.tensor(1.))
    w = pyro.sample("weight", dist.Normal(a, torch.abs(b)))
    print("Scale parametrized guide fn")
    print("a =",a,"b =",b,"weight =",w)
    return w

# %% [markdown]
# As an aside, note that in `scale_parametrized_guide`, we had to apply `torch.abs` to parameter `b` because the standard deviation of a normal distribution has to be positive; similar restrictions also apply to parameters of many other distributions. The PyTorch distributions library, which Pyro is built on, includes a [constraints module](https://pytorch.org/docs/master/distributions.html#module-torch.distributions.constraints) for enforcing such restrictions, and applying constraints to Pyro parameters is as easy as passing the relevant `constraint` object to `pyro.param`:

# %%
from torch.distributions import constraints

def scale_parametrized_guide_constrained(guess):
    a = pyro.param("a", torch.tensor(guess))
    b = pyro.param("b", torch.tensor(1.), constraint=constraints.positive)
    return pyro.sample("weight", dist.Normal(a, b))  # no more torch.abs

# %% [markdown]
# Pyro is built to enable *stochastic variational inference*, a powerful and widely applicable class of variational inference algorithms with three key characteristics:
#
# 1. Parameters are always real-valued tensors
# 2. We compute Monte Carlo estimates of a loss function from samples of execution histories of the model and guide
# 3. We use stochastic gradient descent to search for the optimal parameters.
#
# Combining stochastic gradient descent with PyTorch's GPU-accelerated tensor math and automatic differentiation allows us to scale variational inference to very high-dimensional parameter spaces and massive datasets.
#
# Pyro's SVI functionality is described in detail in the [SVI tutorial](svi_part_i.ipynb). Here is a very simple example applying it to `scale`:

# %%
guess = 8.5

pyro.clear_param_store()
svi = pyro.infer.SVI(model=conditioned_scale, 
                     guide=scale_parametrized_guide,
                     optim=pyro.optim.SGD({"lr": 0.001, "momentum":0.1}),
                     loss=pyro.infer.Trace_ELBO())


losses, a,b  = [], [], []
num_steps = 250
for t in range(num_steps):
    losses.append(svi.step(guess))
    a.append(pyro.param("a").item())
    b.append(pyro.param("b").item())
    
plt.plot(losses)
plt.title("ELBO")
plt.xlabel("step")
plt.ylabel("loss");
print('a = ',pyro.param("a").item())
print('b = ', pyro.param("b").item())
# Out:
# Scale parametrized guide fn
# a = tensor(8.5000, requires_grad=True) b = tensor(1., requires_grad=True) weight = tensor(7.7817, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(7.7817, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(9.5880, requires_grad=True) b = tensor(0.2194, requires_grad=True) weight = tensor(9.6390, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(9.6390, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.0401, requires_grad=True) b = tensor(0.2257, requires_grad=True) weight = tensor(10.1801, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.1801, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.2116, requires_grad=True) b = tensor(0.3091, requires_grad=True) weight = tensor(9.6809, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(9.6809, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5552, requires_grad=True) b = tensor(-0.2398, requires_grad=True) weight = tensor(10.5381, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5381, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5723, requires_grad=True) b = tensor(-0.3001, requires_grad=True) weight = tensor(10.7141, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.7141, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4861, requires_grad=True) b = tensor(-0.2679, requires_grad=True) weight = tensor(10.0395, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.0395, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6602, requires_grad=True) b = tensor(0.0361, requires_grad=True) weight = tensor(10.6569, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6569, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6127, requires_grad=True) b = tensor(0.1001, requires_grad=True) weight = tensor(10.5355, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5355, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5917, requires_grad=True) b = tensor(0.1290, requires_grad=True) weight = tensor(10.6533, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6533, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5261, requires_grad=True) b = tensor(0.1094, requires_grad=True) weight = tensor(10.6070, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6070, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4746, requires_grad=True) b = tensor(0.0833, requires_grad=True) weight = tensor(10.4534, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4534, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4862, requires_grad=True) b = tensor(0.0885, requires_grad=True) weight = tensor(10.5672, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5672, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4584, requires_grad=True) b = tensor(0.0738, requires_grad=True) weight = tensor(10.3841, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3841, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5001, requires_grad=True) b = tensor(0.0411, requires_grad=True) weight = tensor(10.5465, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5465, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4836, requires_grad=True) b = tensor(0.0388, requires_grad=True) weight = tensor(10.4829, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4829, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4868, requires_grad=True) b = tensor(0.0643, requires_grad=True) weight = tensor(10.4722, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4722, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4963, requires_grad=True) b = tensor(0.0803, requires_grad=True) weight = tensor(10.4361, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4361, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5208, requires_grad=True) b = tensor(0.0767, requires_grad=True) weight = tensor(10.5089, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5089, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5177, requires_grad=True) b = tensor(0.0902, requires_grad=True) weight = tensor(10.4396, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4396, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5396, requires_grad=True) b = tensor(0.0834, requires_grad=True) weight = tensor(10.6084, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6084, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4963, requires_grad=True) b = tensor(0.0573, requires_grad=True) weight = tensor(10.5478, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5478, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4708, requires_grad=True) b = tensor(0.0531, requires_grad=True) weight = tensor(10.5096, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5096, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4624, requires_grad=True) b = tensor(0.0672, requires_grad=True) weight = tensor(10.5342, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5342, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4459, requires_grad=True) b = tensor(0.0667, requires_grad=True) weight = tensor(10.4611, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4611, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4578, requires_grad=True) b = tensor(0.0848, requires_grad=True) weight = tensor(10.5470, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5470, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4381, requires_grad=True) b = tensor(0.0764, requires_grad=True) weight = tensor(10.2899, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2899, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5184, requires_grad=True) b = tensor(-0.0709, requires_grad=True) weight = tensor(10.4973, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4973, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5255, requires_grad=True) b = tensor(-0.1000, requires_grad=True) weight = tensor(10.5248, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5248, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5143, requires_grad=True) b = tensor(-0.1130, requires_grad=True) weight = tensor(10.5518, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5518, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4904, requires_grad=True) b = tensor(-0.1156, requires_grad=True) weight = tensor(10.4133, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4133, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5207, requires_grad=True) b = tensor(-0.1027, requires_grad=True) weight = tensor(10.5726, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5726, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4926, requires_grad=True) b = tensor(-0.0954, requires_grad=True) weight = tensor(10.4501, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4501, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5078, requires_grad=True) b = tensor(-0.0971, requires_grad=True) weight = tensor(10.5509, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5509, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4869, requires_grad=True) b = tensor(-0.0976, requires_grad=True) weight = tensor(10.4531, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4531, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5017, requires_grad=True) b = tensor(-0.1021, requires_grad=True) weight = tensor(10.2948, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2948, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5834, requires_grad=True) b = tensor(0.0504, requires_grad=True) weight = tensor(10.6178, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6178, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5424, requires_grad=True) b = tensor(0.0519, requires_grad=True) weight = tensor(10.4957, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4957, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5380, requires_grad=True) b = tensor(0.0715, requires_grad=True) weight = tensor(10.5567, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5567, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5128, requires_grad=True) b = tensor(0.0810, requires_grad=True) weight = tensor(10.5638, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5638, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4827, requires_grad=True) b = tensor(0.0770, requires_grad=True) weight = tensor(10.5360, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5360, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4633, requires_grad=True) b = tensor(0.0782, requires_grad=True) weight = tensor(10.4680, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4680, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4722, requires_grad=True) b = tensor(0.0917, requires_grad=True) weight = tensor(10.3720, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3720, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5224, requires_grad=True) b = tensor(0.0501, requires_grad=True) weight = tensor(10.5494, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5494, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5056, requires_grad=True) b = tensor(0.0541, requires_grad=True) weight = tensor(10.5116, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5116, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4972, requires_grad=True) b = tensor(0.0723, requires_grad=True) weight = tensor(10.3326, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3326, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5615, requires_grad=True) b = tensor(-0.0605, requires_grad=True) weight = tensor(10.5250, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5250, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5560, requires_grad=True) b = tensor(-0.0976, requires_grad=True) weight = tensor(10.6060, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6060, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5109, requires_grad=True) b = tensor(-0.0887, requires_grad=True) weight = tensor(10.4766, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4766, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5137, requires_grad=True) b = tensor(-0.0962, requires_grad=True) weight = tensor(10.4408, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4408, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5358, requires_grad=True) b = tensor(-0.0909, requires_grad=True) weight = tensor(10.6082, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6082, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4926, requires_grad=True) b = tensor(-0.0652, requires_grad=True) weight = tensor(10.5365, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5365, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4716, requires_grad=True) b = tensor(-0.0667, requires_grad=True) weight = tensor(10.6255, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6255, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4172, requires_grad=True) b = tensor(0.0388, requires_grad=True) weight = tensor(10.4214, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4214, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4413, requires_grad=True) b = tensor(0.0783, requires_grad=True) weight = tensor(10.4494, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4494, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4620, requires_grad=True) b = tensor(0.0970, requires_grad=True) weight = tensor(10.4375, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4375, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4871, requires_grad=True) b = tensor(0.1033, requires_grad=True) weight = tensor(10.6499, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6499, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4275, requires_grad=True) b = tensor(0.0158, requires_grad=True) weight = tensor(10.4458, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4458, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4413, requires_grad=True) b = tensor(0.0933, requires_grad=True) weight = tensor(10.3592, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3592, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4971, requires_grad=True) b = tensor(0.0638, requires_grad=True) weight = tensor(10.5250, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5250, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4907, requires_grad=True) b = tensor(0.0713, requires_grad=True) weight = tensor(10.4115, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4115, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5235, requires_grad=True) b = tensor(0.0489, requires_grad=True) weight = tensor(10.5295, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5295, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5129, requires_grad=True) b = tensor(0.0654, requires_grad=True) weight = tensor(10.4835, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4835, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5165, requires_grad=True) b = tensor(0.0803, requires_grad=True) weight = tensor(10.5360, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5360, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5004, requires_grad=True) b = tensor(0.0902, requires_grad=True) weight = tensor(10.4694, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4694, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5091, requires_grad=True) b = tensor(0.0988, requires_grad=True) weight = tensor(10.6046, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6046, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4660, requires_grad=True) b = tensor(0.0673, requires_grad=True) weight = tensor(10.4064, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4064, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4973, requires_grad=True) b = tensor(0.0475, requires_grad=True) weight = tensor(10.5623, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5623, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4734, requires_grad=True) b = tensor(0.0296, requires_grad=True) weight = tensor(10.5078, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5078, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4659, requires_grad=True) b = tensor(0.0557, requires_grad=True) weight = tensor(10.4811, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4811, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4708, requires_grad=True) b = tensor(0.0778, requires_grad=True) weight = tensor(10.5467, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5467, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4505, requires_grad=True) b = tensor(0.0726, requires_grad=True) weight = tensor(10.3235, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3235, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5172, requires_grad=True) b = tensor(-0.0345, requires_grad=True) weight = tensor(10.5117, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5117, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5172, requires_grad=True) b = tensor(-0.0753, requires_grad=True) weight = tensor(10.5177, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5177, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5081, requires_grad=True) b = tensor(-0.0926, requires_grad=True) weight = tensor(10.5755, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5755, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4749, requires_grad=True) b = tensor(-0.0816, requires_grad=True) weight = tensor(10.4891, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4891, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4740, requires_grad=True) b = tensor(-0.0932, requires_grad=True) weight = tensor(10.4719, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4719, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4832, requires_grad=True) b = tensor(-0.1049, requires_grad=True) weight = tensor(10.4504, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4504, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5020, requires_grad=True) b = tensor(-0.1100, requires_grad=True) weight = tensor(10.5351, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5351, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4878, requires_grad=True) b = tensor(-0.1147, requires_grad=True) weight = tensor(10.3032, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3032, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5633, requires_grad=True) b = tensor(-0.0002, requires_grad=True) weight = tensor(10.5638, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5638, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5433, requires_grad=True) b = tensor(-4.7360, requires_grad=True) weight = tensor(5.4864, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(5.4864, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(12.5497, requires_grad=True) b = tensor(-3.0653, requires_grad=True) weight = tensor(10.4889, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4889, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(12.7528, requires_grad=True) b = tensor(-2.8969, requires_grad=True) weight = tensor(13.5323, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(13.5323, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(11.5552, requires_grad=True) b = tensor(-2.5527, requires_grad=True) weight = tensor(8.6908, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(8.6908, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(12.1589, requires_grad=True) b = tensor(-1.7069, requires_grad=True) weight = tensor(11.0753, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(11.0753, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(11.9866, requires_grad=True) b = tensor(-1.7706, requires_grad=True) weight = tensor(10.8880, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.8880, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(11.8117, requires_grad=True) b = tensor(-1.8753, requires_grad=True) weight = tensor(15.1098, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(15.1098, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(9.9437, requires_grad=True) b = tensor(1.3681, requires_grad=True) weight = tensor(8.7849, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(8.7849, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4427, requires_grad=True) b = tensor(1.1124, requires_grad=True) weight = tensor(10.0179, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.0179, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6839, requires_grad=True) b = tensor(1.0147, requires_grad=True) weight = tensor(10.7774, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.7774, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5948, requires_grad=True) b = tensor(0.9954, requires_grad=True) weight = tensor(10.0417, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.0417, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.7677, requires_grad=True) b = tensor(0.8935, requires_grad=True) weight = tensor(11.5682, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(11.5682, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.3546, requires_grad=True) b = tensor(0.4989, requires_grad=True) weight = tensor(10.8223, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.8223, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.1821, requires_grad=True) b = tensor(0.3384, requires_grad=True) weight = tensor(10.3296, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3296, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.2312, requires_grad=True) b = tensor(0.3542, requires_grad=True) weight = tensor(10.5700, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5700, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.2060, requires_grad=True) b = tensor(0.3298, requires_grad=True) weight = tensor(9.7895, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(9.7895, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4864, requires_grad=True) b = tensor(-0.0269, requires_grad=True) weight = tensor(10.4570, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4570, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5297, requires_grad=True) b = tensor(-0.0831, requires_grad=True) weight = tensor(10.6545, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6545, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4701, requires_grad=True) b = tensor(-0.0047, requires_grad=True) weight = tensor(10.4760, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4760, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4717, requires_grad=True) b = tensor(-0.2215, requires_grad=True) weight = tensor(10.4939, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4939, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4723, requires_grad=True) b = tensor(-0.2478, requires_grad=True) weight = tensor(10.6724, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6724, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4013, requires_grad=True) b = tensor(-0.1970, requires_grad=True) weight = tensor(10.2843, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2843, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4787, requires_grad=True) b = tensor(-0.1469, requires_grad=True) weight = tensor(10.2987, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2987, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5651, requires_grad=True) b = tensor(-0.0522, requires_grad=True) weight = tensor(10.6117, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6117, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5270, requires_grad=True) b = tensor(-0.0202, requires_grad=True) weight = tensor(10.5374, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5374, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5062, requires_grad=True) b = tensor(-0.0578, requires_grad=True) weight = tensor(10.5006, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5006, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5019, requires_grad=True) b = tensor(-0.0791, requires_grad=True) weight = tensor(10.4929, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4929, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5022, requires_grad=True) b = tensor(-0.0937, requires_grad=True) weight = tensor(10.5296, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5296, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4884, requires_grad=True) b = tensor(-0.1018, requires_grad=True) weight = tensor(10.5909, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5909, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4486, requires_grad=True) b = tensor(-0.0738, requires_grad=True) weight = tensor(10.4670, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4670, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4558, requires_grad=True) b = tensor(-0.0873, requires_grad=True) weight = tensor(10.4299, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4299, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4827, requires_grad=True) b = tensor(-0.0924, requires_grad=True) weight = tensor(10.5240, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5240, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4737, requires_grad=True) b = tensor(-0.0985, requires_grad=True) weight = tensor(10.4024, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4024, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5100, requires_grad=True) b = tensor(-0.0823, requires_grad=True) weight = tensor(10.4475, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4475, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5326, requires_grad=True) b = tensor(-0.0784, requires_grad=True) weight = tensor(10.5209, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5209, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5245, requires_grad=True) b = tensor(-0.0923, requires_grad=True) weight = tensor(10.4078, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4078, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5586, requires_grad=True) b = tensor(-0.0604, requires_grad=True) weight = tensor(10.6227, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6227, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5108, requires_grad=True) b = tensor(-0.0194, requires_grad=True) weight = tensor(10.5082, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5082, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5008, requires_grad=True) b = tensor(-0.0676, requires_grad=True) weight = tensor(10.5851, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5851, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4636, requires_grad=True) b = tensor(-0.0421, requires_grad=True) weight = tensor(10.3947, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3947, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5002, requires_grad=True) b = tensor(0.0025, requires_grad=True) weight = tensor(10.5040, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5040, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5002, requires_grad=True) b = tensor(0.4035, requires_grad=True) weight = tensor(10.1793, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.1793, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6268, requires_grad=True) b = tensor(0.3454, requires_grad=True) weight = tensor(11.0184, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(11.0184, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4296, requires_grad=True) b = tensor(0.1045, requires_grad=True) weight = tensor(10.4313, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4313, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4354, requires_grad=True) b = tensor(0.0904, requires_grad=True) weight = tensor(10.5458, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5458, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4156, requires_grad=True) b = tensor(0.0753, requires_grad=True) weight = tensor(10.4894, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4894, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4159, requires_grad=True) b = tensor(0.0892, requires_grad=True) weight = tensor(10.3788, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3788, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4625, requires_grad=True) b = tensor(0.0825, requires_grad=True) weight = tensor(10.4639, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4639, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4797, requires_grad=True) b = tensor(0.0941, requires_grad=True) weight = tensor(10.3361, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3361, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5451, requires_grad=True) b = tensor(0.0087, requires_grad=True) weight = tensor(10.5435, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5435, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5322, requires_grad=True) b = tensor(0.1185, requires_grad=True) weight = tensor(10.7625, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.7625, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4237, requires_grad=True) b = tensor(-0.0705, requires_grad=True) weight = tensor(10.3938, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3938, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4534, requires_grad=True) b = tensor(-0.0864, requires_grad=True) weight = tensor(10.5074, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5074, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4514, requires_grad=True) b = tensor(-0.0964, requires_grad=True) weight = tensor(10.3950, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3950, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4913, requires_grad=True) b = tensor(-0.0844, requires_grad=True) weight = tensor(10.4786, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4786, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5018, requires_grad=True) b = tensor(-0.0940, requires_grad=True) weight = tensor(10.5213, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5213, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4924, requires_grad=True) b = tensor(-0.1035, requires_grad=True) weight = tensor(10.7480, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.7480, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.3900, requires_grad=True) b = tensor(0.1365, requires_grad=True) weight = tensor(10.4250, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4250, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4078, requires_grad=True) b = tensor(0.1750, requires_grad=True) weight = tensor(10.3400, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3400, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4717, requires_grad=True) b = tensor(0.1605, requires_grad=True) weight = tensor(10.5271, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5271, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4653, requires_grad=True) b = tensor(0.1609, requires_grad=True) weight = tensor(10.3970, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3970, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5039, requires_grad=True) b = tensor(0.1504, requires_grad=True) weight = tensor(10.3926, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3926, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5488, requires_grad=True) b = tensor(0.1257, requires_grad=True) weight = tensor(10.4901, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4901, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5553, requires_grad=True) b = tensor(0.1302, requires_grad=True) weight = tensor(10.6440, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6440, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4962, requires_grad=True) b = tensor(0.0977, requires_grad=True) weight = tensor(10.4753, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4753, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4982, requires_grad=True) b = tensor(0.1029, requires_grad=True) weight = tensor(10.3823, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3823, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5436, requires_grad=True) b = tensor(0.0623, requires_grad=True) weight = tensor(10.5162, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5162, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5397, requires_grad=True) b = tensor(0.0780, requires_grad=True) weight = tensor(10.5511, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5511, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5168, requires_grad=True) b = tensor(0.0891, requires_grad=True) weight = tensor(10.4912, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4912, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5160, requires_grad=True) b = tensor(0.1010, requires_grad=True) weight = tensor(10.6164, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6164, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4673, requires_grad=True) b = tensor(0.0637, requires_grad=True) weight = tensor(10.6136, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6136, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4148, requires_grad=True) b = tensor(-0.0335, requires_grad=True) weight = tensor(10.4142, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4142, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4420, requires_grad=True) b = tensor(-0.0724, requires_grad=True) weight = tensor(10.4955, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4955, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4445, requires_grad=True) b = tensor(-0.0900, requires_grad=True) weight = tensor(10.5935, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5935, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4053, requires_grad=True) b = tensor(-0.0375, requires_grad=True) weight = tensor(10.3733, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3733, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4502, requires_grad=True) b = tensor(-0.0172, requires_grad=True) weight = tensor(10.4210, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4210, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4844, requires_grad=True) b = tensor(-0.0230, requires_grad=True) weight = tensor(10.4765, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4765, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4952, requires_grad=True) b = tensor(-0.0646, requires_grad=True) weight = tensor(10.5214, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5214, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4857, requires_grad=True) b = tensor(-0.0799, requires_grad=True) weight = tensor(10.4550, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4550, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5008, requires_grad=True) b = tensor(-0.0878, requires_grad=True) weight = tensor(10.4856, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4856, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5061, requires_grad=True) b = tensor(-0.0993, requires_grad=True) weight = tensor(10.5415, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5415, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4880, requires_grad=True) b = tensor(-0.1039, requires_grad=True) weight = tensor(10.5415, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5415, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4675, requires_grad=True) b = tensor(-0.1043, requires_grad=True) weight = tensor(10.1496, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.1496, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6039, requires_grad=True) b = tensor(0.3080, requires_grad=True) weight = tensor(10.3050, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3050, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6938, requires_grad=True) b = tensor(0.2785, requires_grad=True) weight = tensor(10.5813, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5813, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6682, requires_grad=True) b = tensor(0.2931, requires_grad=True) weight = tensor(10.5948, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5948, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.6256, requires_grad=True) b = tensor(0.3080, requires_grad=True) weight = tensor(10.8660, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.8660, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4726, requires_grad=True) b = tensor(0.1966, requires_grad=True) weight = tensor(10.6323, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6323, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4022, requires_grad=True) b = tensor(0.1459, requires_grad=True) weight = tensor(10.1738, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.1738, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5240, requires_grad=True) b = tensor(-0.0540, requires_grad=True) weight = tensor(10.5535, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5535, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5127, requires_grad=True) b = tensor(-0.0797, requires_grad=True) weight = tensor(10.5149, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5149, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5036, requires_grad=True) b = tensor(-0.0946, requires_grad=True) weight = tensor(10.4987, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4987, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5012, requires_grad=True) b = tensor(-0.1067, requires_grad=True) weight = tensor(10.5289, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5289, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4874, requires_grad=True) b = tensor(-0.1138, requires_grad=True) weight = tensor(10.5813, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5813, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4514, requires_grad=True) b = tensor(-0.0947, requires_grad=True) weight = tensor(10.6224, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6224, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.3967, requires_grad=True) b = tensor(-0.0111, requires_grad=True) weight = tensor(10.4005, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4005, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4292, requires_grad=True) b = tensor(-0.1053, requires_grad=True) weight = tensor(10.4723, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4723, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4415, requires_grad=True) b = tensor(-0.1280, requires_grad=True) weight = tensor(10.1926, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.1926, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5640, requires_grad=True) b = tensor(0.0979, requires_grad=True) weight = tensor(10.5390, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5390, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5587, requires_grad=True) b = tensor(0.1352, requires_grad=True) weight = tensor(10.7239, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.7239, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4663, requires_grad=True) b = tensor(0.0341, requires_grad=True) weight = tensor(10.4234, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4234, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4858, requires_grad=True) b = tensor(0.0172, requires_grad=True) weight = tensor(10.4720, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4720, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4970, requires_grad=True) b = tensor(0.0662, requires_grad=True) weight = tensor(10.4346, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4346, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5223, requires_grad=True) b = tensor(0.0634, requires_grad=True) weight = tensor(10.6653, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6653, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4565, requires_grad=True) b = tensor(-0.0751, requires_grad=True) weight = tensor(10.4583, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4583, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4647, requires_grad=True) b = tensor(-0.1026, requires_grad=True) weight = tensor(10.3830, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3830, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5104, requires_grad=True) b = tensor(-0.0793, requires_grad=True) weight = tensor(10.6561, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6561, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4504, requires_grad=True) b = tensor(0.0290, requires_grad=True) weight = tensor(10.4394, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4394, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4667, requires_grad=True) b = tensor(0.0658, requires_grad=True) weight = tensor(10.3999, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3999, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5065, requires_grad=True) b = tensor(0.0460, requires_grad=True) weight = tensor(10.5657, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5657, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4821, requires_grad=True) b = tensor(0.0292, requires_grad=True) weight = tensor(10.4810, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4810, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4853, requires_grad=True) b = tensor(0.0616, requires_grad=True) weight = tensor(10.4411, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4411, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5072, requires_grad=True) b = tensor(0.0655, requires_grad=True) weight = tensor(10.4389, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4389, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5319, requires_grad=True) b = tensor(0.0577, requires_grad=True) weight = tensor(10.4947, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4947, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5345, requires_grad=True) b = tensor(0.0742, requires_grad=True) weight = tensor(10.3977, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3977, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5738, requires_grad=True) b = tensor(0.0174, requires_grad=True) weight = tensor(10.5595, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5595, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5518, requires_grad=True) b = tensor(0.0903, requires_grad=True) weight = tensor(10.5054, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5054, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5454, requires_grad=True) b = tensor(0.1108, requires_grad=True) weight = tensor(10.6148, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6148, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4968, requires_grad=True) b = tensor(0.0918, requires_grad=True) weight = tensor(10.4823, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4823, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4970, requires_grad=True) b = tensor(0.1000, requires_grad=True) weight = tensor(10.4164, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4164, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5286, requires_grad=True) b = tensor(0.0855, requires_grad=True) weight = tensor(10.5196, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5196, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5219, requires_grad=True) b = tensor(0.0967, requires_grad=True) weight = tensor(10.5357, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5357, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5049, requires_grad=True) b = tensor(0.1059, requires_grad=True) weight = tensor(10.5374, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5374, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4862, requires_grad=True) b = tensor(0.1110, requires_grad=True) weight = tensor(10.5529, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5529, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4611, requires_grad=True) b = tensor(0.1065, requires_grad=True) weight = tensor(10.4811, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4811, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4642, requires_grad=True) b = tensor(0.1165, requires_grad=True) weight = tensor(10.4219, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4219, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4938, requires_grad=True) b = tensor(0.1155, requires_grad=True) weight = tensor(10.6388, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6388, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4390, requires_grad=True) b = tensor(0.0516, requires_grad=True) weight = tensor(10.4209, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4209, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4633, requires_grad=True) b = tensor(0.0541, requires_grad=True) weight = tensor(10.3629, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3629, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5187, requires_grad=True) b = tensor(-0.0253, requires_grad=True) weight = tensor(10.5063, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5063, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5197, requires_grad=True) b = tensor(-0.0750, requires_grad=True) weight = tensor(10.5096, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5096, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5139, requires_grad=True) b = tensor(-0.0941, requires_grad=True) weight = tensor(10.6513, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6513, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4507, requires_grad=True) b = tensor(-0.0150, requires_grad=True) weight = tensor(10.4598, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4598, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4585, requires_grad=True) b = tensor(-0.0822, requires_grad=True) weight = tensor(10.5042, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5042, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4556, requires_grad=True) b = tensor(-0.0991, requires_grad=True) weight = tensor(10.2658, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2658, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5472, requires_grad=True) b = tensor(0.0653, requires_grad=True) weight = tensor(10.5683, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5683, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5270, requires_grad=True) b = tensor(0.0876, requires_grad=True) weight = tensor(10.6386, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6386, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4674, requires_grad=True) b = tensor(0.0279, requires_grad=True) weight = tensor(10.4926, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4926, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4624, requires_grad=True) b = tensor(0.0587, requires_grad=True) weight = tensor(10.4282, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4282, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4887, requires_grad=True) b = tensor(0.0632, requires_grad=True) weight = tensor(10.5578, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5578, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4662, requires_grad=True) b = tensor(0.0519, requires_grad=True) weight = tensor(10.4335, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4335, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4886, requires_grad=True) b = tensor(0.0545, requires_grad=True) weight = tensor(10.4393, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4393, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5132, requires_grad=True) b = tensor(0.0529, requires_grad=True) weight = tensor(10.5152, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5152, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5075, requires_grad=True) b = tensor(0.0714, requires_grad=True) weight = tensor(10.5532, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5532, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4836, requires_grad=True) b = tensor(0.0723, requires_grad=True) weight = tensor(10.3226, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3226, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5504, requires_grad=True) b = tensor(-0.0678, requires_grad=True) weight = tensor(10.5917, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5917, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5183, requires_grad=True) b = tensor(-0.0730, requires_grad=True) weight = tensor(10.5337, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5337, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4996, requires_grad=True) b = tensor(-0.0839, requires_grad=True) weight = tensor(10.5429, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5429, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4785, requires_grad=True) b = tensor(-0.0870, requires_grad=True) weight = tensor(10.5049, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5049, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4724, requires_grad=True) b = tensor(-0.0976, requires_grad=True) weight = tensor(10.5917, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5917, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4331, requires_grad=True) b = tensor(-0.0616, requires_grad=True) weight = tensor(10.5015, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5015, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4265, requires_grad=True) b = tensor(-0.0713, requires_grad=True) weight = tensor(10.3874, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3874, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4690, requires_grad=True) b = tensor(-0.0626, requires_grad=True) weight = tensor(10.3861, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.3861, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5170, requires_grad=True) b = tensor(-0.0199, requires_grad=True) weight = tensor(10.4945, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4945, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5220, requires_grad=True) b = tensor(-0.0657, requires_grad=True) weight = tensor(10.5344, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5344, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5067, requires_grad=True) b = tensor(-0.0825, requires_grad=True) weight = tensor(10.5876, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5876, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4680, requires_grad=True) b = tensor(-0.0598, requires_grad=True) weight = tensor(10.6045, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.6045, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4202, requires_grad=True) b = tensor(0.0259, requires_grad=True) weight = tensor(10.4352, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4352, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4395, requires_grad=True) b = tensor(0.0869, requires_grad=True) weight = tensor(10.2957, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.2957, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5213, requires_grad=True) b = tensor(-0.0275, requires_grad=True) weight = tensor(10.5448, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5448, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5095, requires_grad=True) b = tensor(-0.0582, requires_grad=True) weight = tensor(10.5348, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5348, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4923, requires_grad=True) b = tensor(-0.0715, requires_grad=True) weight = tensor(10.4270, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4270, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5179, requires_grad=True) b = tensor(-0.0619, requires_grad=True) weight = tensor(10.5817, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5817, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4857, requires_grad=True) b = tensor(-0.0412, requires_grad=True) weight = tensor(10.4840, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4840, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4869, requires_grad=True) b = tensor(-0.0632, requires_grad=True) weight = tensor(10.4664, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4664, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4985, requires_grad=True) b = tensor(-0.0775, requires_grad=True) weight = tensor(10.5490, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5490, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4780, requires_grad=True) b = tensor(-0.0778, requires_grad=True) weight = tensor(10.5080, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.5080, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.4708, requires_grad=True) b = tensor(-0.0886, requires_grad=True) weight = tensor(10.4034, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4034, grad_fn=<AddBackward0>) measurement = 10.5
# Scale parametrized guide fn
# a = tensor(10.5068, requires_grad=True) b = tensor(-0.0731, requires_grad=True) weight = tensor(10.4685, grad_fn=<AddBackward0>)
# Scale fn
# guess = 8.5 weight = tensor(10.4685, grad_fn=<AddBackward0>) measurement = 10.5
# a =  10.521001815795898
# b =  -0.0796518623828888

# %%
plt.subplot(1,2,1)
plt.plot([0,num_steps],[9.14,9.14], 'k:')
plt.plot(a)
plt.ylabel('a')

plt.subplot(1,2,2)
plt.ylabel('b')
plt.plot([0,num_steps],[0.6,0.6], 'k:')
plt.plot(b)
plt.tight_layout()

# %% [markdown]
# **Note that SVI obtains parameters very close to the true parameters of the desired conditional distribution. This is to be expected as our guide is from the same family.**
#
# Note that optimization will update the values of the guide parameters in the parameter store, so that once we find good parameter values, we can use samples from the guide as posterior samples for downstream tasks.

# %%
# New cell added by Laura
# can we check that these values of a and b (and therefore weight) 
# give corect value of measurement
a_final = pyro.param("a").item()
b_final = pyro.param("b").item()


weights=np.array([(pyro.sample("weight", dist.Normal(a_final, b_final)) )
                  for i in range(10000)])

plt.hist(weights)
# Out:
# (array([  29.,  188.,  746., 1838., 2797., 2537., 1350.,  431.,   72.,
#           12.]),
#  array([10.241247, 10.299603, 10.357961, 10.416317, 10.474673, 10.53303 ,
#         10.591387, 10.649743, 10.708099, 10.766457, 10.824813],
#        dtype=float32),
#  <a list of 10 Patch objects>)

# %%
np.mean(weights)
# Out:
# 10.520554

# %%
conditioned_scale = pyro.condition(scale, data={"weight": a_final})

# %%
measurements =np.array([pyro.sample("measurement", dist.Normal(np.mean(weights), 0.75))
                  for i in range(100)])

# %%
plt.hist(measurements)
# Out:
# (array([ 4., 12.,  8., 10., 19., 13., 17., 10.,  4.,  3.]),
#  array([ 8.868163 ,  9.19011  ,  9.512057 ,  9.834004 , 10.1559515,
#         10.477898 , 10.799845 , 11.121792 , 11.443739 , 11.765686 ,
#         12.087633 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
np.mean(measurements)
# Out:
# 9.184297

# %% [markdown]
# ## Next Steps
#
# In the [Variational Autoencoder tutorial](vae.ipynb), we'll see how models like `scale` can be augmented with deep neural networks and use stochastic variational inference to build a generative model of images.
